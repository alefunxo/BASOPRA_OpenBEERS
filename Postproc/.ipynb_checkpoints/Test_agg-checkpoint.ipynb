# %%
import itertools
import pandas as pd
import numpy as np
import os
import csv
import matplotlib.pyplot as plt
import paper_classes as pc
import df_todo as todo

# %%
df_done=pd.read_csv('Output/aggregated_results.csv',sep=';').drop_duplicates()
print(df_done.shape)
print(df_done.keys())
print(26928-df_done.shape[0])
# Out:
# (6043, 93)
# Index(['E_PV_batt', 'E_PV_bu', 'E_PV_budhw', 'E_PV_curt', 'E_PV_grid',
#        'E_PV_hp', 'E_PV_hpdhw', 'E_PV_load', 'E_batt_bu', 'E_batt_budhw',
#        'E_batt_hp', 'E_batt_hpdhw', 'E_batt_load', 'E_bu', 'E_budhw', 'E_char',
#        'E_cons', 'E_dis', 'E_grid_batt', 'E_grid_bu', 'E_grid_budhw',
#        'E_grid_hp', 'E_grid_hpdhw', 'E_grid_load', 'E_hp', 'E_hpdhw',
#        'E_loss_Batt', 'E_loss_conv', 'E_loss_inv', 'E_loss_inv_PV',
#        'E_loss_inv_batt', 'E_loss_inv_grid', 'Q_dhwst_hd', 'Q_hp_sh',
#        'Q_hp_ts', 'Q_loss_dhwst', 'Q_loss_ts', 'Q_ts', 'Q_ts_delta', 'Q_ts_sh',
#        'T_dhwst', 'T_ts', 'E_demand', 'E_PV', 'Req_kWh', 'Req_kWh_DHW',
#        'Set_T', 'Temp', 'Temp_supply', 'Temp_supply_tank', 'T_aux_supply',
#        'COP_tank', 'COP_SH', 'COP_DHW', 'E_demand_hp_pv_dhw', 'E_demand_hp_pv',
#        'E_demand_pv', 'TSC', 'DSC', 'ISC', 'CU', 'EFC_nolifetime', 'BS', 'LS1',
#        'LS2', 'LS3', 'LS4', 'LS5', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5',
#        'App_comb', 'conf', 'Capacity', 'Tech', 'PV_nom', 'cluster', 'hh',
#        'country', 'quartile', 'cases', 'house_type', 'HP', 'SOC_mean',
#        'P_drained_max', 'P_injected_max', 'last_cap', 'cap_fading', 'last_SOH',
#        'cycle_to_total', 'Bill'],
#       dtype='object')
# 20885

# %%
df_todo=todo.get_combinations_todo(df_done)
# Out:
#       Capacity  App_comb Tech  PV_nom cluster             hh country cases  \
# 6043       7.0       2.0  NMC     4.8     NaN   110143956137      CH  mean
# 6044       7.0       2.0  NMC     4.8     NaN   110699130150      CH  mean
# 6045       7.0       2.0  NMC     4.8     NaN  1127351129756      CH  mean
# 6046       7.0       2.0  NMC     4.8     NaN   110697129369      CH  mean
# 6047       7.0       2.0  NMC     4.8     NaN   110699430243      CH  mean
#
#       conf  HP house_type   0
# 6043   0.0  AS     SFH100 NaN
# 6044   0.0  AS     SFH100 NaN
# 6045   0.0  AS     SFH100 NaN
# 6046   0.0  AS     SFH100 NaN
# 6047   0.0  AS     SFH100 NaN

# %%
len(df_todo.hh.unique())
# Out:
# 561

# %%
len(df_done.hh.unique())
# Out:
# 561

# %%
list_exclure=todo.hh.unique()

# %%
#df=pd.read_csv('old_csv_final.csv',sep=',').drop_duplicates()
df=pd.read_csv('Output/aggregated_results_normalCT.csv',sep=';').drop_duplicates()


print(df.shape)
print(df.keys())
# Out:
# (26916, 93)
# Index(['E_PV_batt', 'E_PV_bu', 'E_PV_budhw', 'E_PV_curt', 'E_PV_grid',
#        'E_PV_hp', 'E_PV_hpdhw', 'E_PV_load', 'E_batt_bu', 'E_batt_budhw',
#        'E_batt_hp', 'E_batt_hpdhw', 'E_batt_load', 'E_bu', 'E_budhw', 'E_char',
#        'E_cons', 'E_dis', 'E_grid_batt', 'E_grid_bu', 'E_grid_budhw',
#        'E_grid_hp', 'E_grid_hpdhw', 'E_grid_load', 'E_hp', 'E_hpdhw',
#        'E_loss_Batt', 'E_loss_conv', 'E_loss_inv', 'E_loss_inv_PV',
#        'E_loss_inv_batt', 'E_loss_inv_grid', 'Q_dhwst_hd', 'Q_hp_sh',
#        'Q_hp_ts', 'Q_loss_dhwst', 'Q_loss_ts', 'Q_ts', 'Q_ts_delta', 'Q_ts_sh',
#        'T_dhwst', 'T_ts', 'E_demand', 'E_PV', 'Req_kWh', 'Req_kWh_DHW',
#        'Set_T', 'Temp', 'Temp_supply', 'Temp_supply_tank', 'T_aux_supply',
#        'COP_tank', 'COP_SH', 'COP_DHW', 'E_demand_hp_pv_dhw', 'E_demand_hp_pv',
#        'E_demand_pv', 'TSC', 'DSC', 'ISC', 'CU', 'EFC_nolifetime', 'BS', 'LS1',
#        'LS2', 'LS3', 'LS4', 'LS5', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5',
#        'App_comb', 'conf', 'Capacity', 'Tech', 'PV_nom', 'cluster', 'hh',
#        'country', 'quartile', 'cases', 'house_type', 'HP', 'SOC_mean',
#        'P_drained_max', 'P_injected_max', 'last_cap', 'cap_fading', 'last_SOH',
#        'cycle_to_total', 'Bill'],
#       dtype='object')

# %%
title_size=20
large_size=18
normal_size=16
medium_size=14
small_size=12
project_life=30

# %%
def plot_boxplot(df,col,list_by):
    '''
    Description
    -----------
    Boxplots of column 'col'. The Dataframe is grouped by pv penetration (pv) and battery penetration (batt) if not None.
    Parameters
    -----------
    df (pd.Series): Single row of the pd.Dataframe (for a single PV and Battery penetration)
    Returns
    -----------
    None
    '''
    plt.figure(figsize=(20,20))
    size=16
    size2=12
    color=['blue', 'cyan','lime', 'red', 'green','orange']
    bp=df.round(3).boxplot(by=list_by,
                   column=col, 
                   grid=False)
#    tuples=[tuple(x) for x in df.loc[:,['house_type','cluster']].values]
    
    plt.draw()
    bp.set_ylabel(col,size=size)
    bp.set_yticklabels([item.get_text() for item in bp.get_yticklabels()],fontsize=size2)
    bp.set_xlabel('Type of house',size=normal_size)
    bp.set_xticklabels([item.get_text() for item in bp.get_xticklabels()],fontsize=size2)

    bp.set_title('')
    plt.xticks( rotation='vertical')
    plt.suptitle('')
    if col=='bill' and not(pv and batt):
        bp.axhline(y=0, color='k')

# %% [markdown]
# ## DHW provision using the HP may increase the TSC between 9% and 14% (absolute difference).

# %%
list_gb=['house_type','conf']
df.groupby(list_gb).TSC.mean()
# Out:
# house_type  conf
# SFH100      0.0     22.767598
#             1.0     36.012339
#             2.0     28.913401
#             3.0     38.587722
#             4.0     38.779208
#             5.0     48.344222
#             6.0     40.045530
#             7.0     48.418576
# SFH15       0.0     17.132676
#             1.0     30.037618
#             2.0     20.008697
#             3.0     31.258369
#             4.0     32.385231
#             5.0     42.604890
#             6.0     32.572605
#             7.0     42.524139
# SFH45       0.0     19.978719
#             1.0     31.921165
#             2.0     24.585143
#             3.0     34.004212
#             4.0     35.882657
#             5.0     44.697514
#             6.0     36.097775
#             7.0     44.539790
# Name: TSC, dtype: float64

# %%
df.groupby(list_gb).TSC.mean().diff(periods = 1).reset_index()[df.groupby(list_gb).TSC.mean().diff(periods = 1).reset_index().conf%2==1]
# Out:
#    house_type  conf        TSC
# 1      SFH100   1.0  13.244741
# 3      SFH100   3.0   9.674321
# 5      SFH100   5.0   9.565015
# 7      SFH100   7.0   8.373046
# 9       SFH15   1.0  12.904942
# 11      SFH15   3.0  11.249673
# 13      SFH15   5.0  10.219659
# 15      SFH15   7.0   9.951534
# 17      SFH45   1.0  11.942447
# 19      SFH45   3.0   9.419069
# 21      SFH45   5.0   8.814856
# 23      SFH45   7.0   8.442015

# %%
df.keys()
# Out:
# Index(['E_PV_batt', 'E_PV_bu', 'E_PV_budhw', 'E_PV_curt', 'E_PV_grid',
#        'E_PV_hp', 'E_PV_hpdhw', 'E_PV_load', 'E_batt_bu', 'E_batt_budhw',
#        'E_batt_hp', 'E_batt_hpdhw', 'E_batt_load', 'E_bu', 'E_budhw', 'E_char',
#        'E_cons', 'E_dis', 'E_grid_batt', 'E_grid_bu', 'E_grid_budhw',
#        'E_grid_hp', 'E_grid_hpdhw', 'E_grid_load', 'E_hp', 'E_hpdhw',
#        'E_loss_Batt', 'E_loss_conv', 'E_loss_inv', 'E_loss_inv_PV',
#        'E_loss_inv_batt', 'E_loss_inv_grid', 'Q_dhwst_hd', 'Q_hp_sh',
#        'Q_hp_ts', 'Q_loss_dhwst', 'Q_loss_ts', 'Q_ts', 'Q_ts_delta', 'Q_ts_sh',
#        'T_dhwst', 'T_ts', 'E_demand', 'E_PV', 'Req_kWh', 'Req_kWh_DHW',
#        'Set_T', 'Temp', 'Temp_supply', 'Temp_supply_tank', 'T_aux_supply',
#        'COP_tank', 'COP_SH', 'COP_DHW', 'E_demand_hp_pv_dhw', 'E_demand_hp_pv',
#        'E_demand_pv', 'TSC', 'DSC', 'ISC', 'CU', 'EFC_nolifetime', 'BS', 'LS1',
#        'LS2', 'LS3', 'LS4', 'LS5', 'PS1', 'PS2', 'PS3', 'PS4', 'PS5',
#        'App_comb', 'conf', 'Capacity', 'Tech', 'PV_nom', 'cluster', 'hh',
#        'country', 'quartile', 'cases', 'house_type', 'HP', 'SOC_mean',
#        'P_drained_max', 'P_injected_max', 'last_cap', 'cap_fading', 'last_SOH',
#        'cycle_to_total', 'Bill'],
#       dtype='object')

# %% [markdown]
# ### The use of the capacity tariff may reduce the average required power of a single family house between 11% (0.6 kW) and 70% (18.76 kW)  when a tank is used (compared to a house performing DLS using the HP) this will required a detailed explanation

# %% [markdown]
# ### However, when DHW is included, the power reduction is more limited (except in conf 4 and 5 i.e. hp with batt and hp with batt and dhw)

# %% [markdown]
# In the abscence of a storage tank for SH, DHW storage tank helps to reduce the required power

# %%
list_gb=['house_type','conf','App_comb']
df.groupby(list_gb).P_drained_max.mean()
# Out:
# house_type  conf  App_comb
# SFH100      0.0   2.0          9.526341
#                   3.0          9.526341
#             1.0   2.0         18.461379
#                   3.0         15.220697
#             2.0   2.0         24.316269
#                   3.0          8.017650
#             3.0   2.0         24.352368
#                   3.0         15.243965
#             4.0   2.0         10.964295
#                   3.0          7.424331
#             5.0   2.0         20.831597
#                   3.0         15.219197
#             6.0   2.0         26.686379
#                   3.0          7.925204
#             7.0   2.0         26.759608
#                   3.0         15.242590
# SFH15       0.0   2.0          4.937609
#                   3.0          4.937609
#             1.0   2.0          5.402531
#                   3.0          4.774544
#             2.0   2.0          7.847445
#                   3.0          4.758240
#             3.0   2.0          7.978788
#                   3.0          4.795546
#             4.0   2.0          5.638899
#                   3.0          2.900221
#             5.0   2.0          6.769241
#                   3.0          3.138598
#             6.0   2.0         10.303089
#                   3.0          3.176570
#             7.0   2.0         10.315085
#                   3.0          3.354647
# SFH45       0.0   2.0          5.302821
#                   3.0          5.302821
#             1.0   2.0          6.591988
#                   3.0          5.041338
#             2.0   2.0         10.249342
#                   3.0          4.812776
#             3.0   2.0         10.318258
#                   3.0          5.045451
#             4.0   2.0          6.162887
#                   3.0          3.276285
#             5.0   2.0          8.457703
#                   3.0          4.127879
#             6.0   2.0         12.120773
#                   3.0          3.438716
#             7.0   2.0         12.166587
#                   3.0          4.150420
# Name: P_drained_max, dtype: float64

# %%
df.groupby(list_gb).P_drained_max.mean().diff(periods = 1).reset_index()[df.groupby(list_gb).P_drained_max.mean().diff(periods = 1).reset_index().App_comb%2==1].round(2)
# Out:
#    house_type  conf  App_comb  P_drained_max
# 1      SFH100   0.0       3.0           0.00
# 3      SFH100   1.0       3.0          -3.24
# 5      SFH100   2.0       3.0         -16.30
# 7      SFH100   3.0       3.0          -9.11
# 9      SFH100   4.0       3.0          -3.54
# 11     SFH100   5.0       3.0          -5.61
# 13     SFH100   6.0       3.0         -18.76
# 15     SFH100   7.0       3.0         -11.52
# 17      SFH15   0.0       3.0          -0.00
# 19      SFH15   1.0       3.0          -0.63
# 21      SFH15   2.0       3.0          -3.09
# 23      SFH15   3.0       3.0          -3.18
# 25      SFH15   4.0       3.0          -2.74
# 27      SFH15   5.0       3.0          -3.63
# 29      SFH15   6.0       3.0          -7.13
# 31      SFH15   7.0       3.0          -6.96
# 33      SFH45   0.0       3.0           0.00
# 35      SFH45   1.0       3.0          -1.55
# 37      SFH45   2.0       3.0          -5.44
# 39      SFH45   3.0       3.0          -5.27
# 41      SFH45   4.0       3.0          -2.89
# 43      SFH45   5.0       3.0          -4.33
# 45      SFH45   6.0       3.0          -8.68
# 47      SFH45   7.0       3.0          -8.02

# %% [markdown]
# ### In average the battery charged from the grid 13% of the used electricity [2.4% - 35%] usually done while prices are low i.e. in the morning and late in the evening. So what does it means for CO2 emissions? When capacity tariff, the amount of electricity charged from the grid is lower.

# %%
(df[(df.conf>3)&(df.App_comb==2)].E_grid_batt/df[df.conf>3&(df.App_comb==2)].E_cons).min()
# Out:
# 0.0777272034630977

# %%
(df[(df.conf>3)&(df.App_comb==2)].E_grid_batt/df[df.conf>3&(df.App_comb==2)].E_cons).max()
# Out:
# 0.35777727897523104

# %%
(df[(df.conf>3)&(df.App_comb==3)].E_grid_batt/df[df.conf>3&(df.App_comb==3)].E_cons).min()
# Out:
# 0.024272108984005437

# %%
(df[(df.conf>3)&(df.App_comb==3)].E_grid_batt/df[df.conf>3&(df.App_comb==3)].E_cons).max()
# Out:
# 0.24801559843761747

# %%
(df[(df.conf>3)&(df.App_comb==2)].E_grid_batt/df[df.conf>3&(df.App_comb==2)].E_cons).mean()
# Out:
# 0.16183656110003014

# %%
(df[(df.conf>3)&(df.App_comb==3)].E_grid_batt/df[df.conf>3&(df.App_comb==3)].E_cons).mean()
# Out:
# 0.09143406886313901

# %%
df.E_grid_batt.max()
# Out:
# 1109.6212200643795

# %%
df.loc[df.E_budhw==df.E_budhw.max(),['App_comb','conf','house_type','E_budhw']]
# Out:
#        App_comb  conf house_type    E_budhw
# 21440       2.0   1.0      SFH15  14.284438

# %%
plot_boxplot(df,'TSC',['house_type','App_comb'])

# %% [markdown]
# # --------------------------------------------------------------------------------------------------

# %% [markdown]
# # LCOES

# %% [markdown]
# Battery degradation is assumed. However, heat pump nor PV degradation are considered.
#
# Meaning that all years the heat pump consumes the same amount of electricity until it is replaced and the PV system always provides the same amount of electricty.
#
# Here we do not include the changes in irradiance either.

# %% [markdown]
# # PV O&M are too high (comparable to the bill in some cases)

# %%
project_life=30 #or 25 years
discount_rate=0.04
fraction=1

# %% [markdown]
# #### For the Levelized cost of electricity of the system, it is required to use the total electricity demand to cover the load, the heat pump demand and the battery charging from the grid.
# #### I.e. the average cost per unit electricity delivered to the end-user customer is determined.

# %%
def get_battery_lifetime(row):
    if row.loc['cases']=='False':
        Batt=pc.Battery_tech(Capacity=row.loc['Capacity'],Technology=row['Tech'])  
    else:
        Batt=pc.Battery_case(Capacity=row.loc['Capacity'],Technology=row['Tech'],case=row['cases'])  
    m=(row.Capacity-row.last_cap)/(0-365)
    x=(row.Capacity*0.7-row.Capacity)/m
    
    #investment=get_investment(row,Batt)
    return [min(int(x/365+1),Batt.Battery_cal_life)]

# %%
PV=[{'PV':3.2,'quartile':25,'country':'US'},
        {'PV':5,'quartile':50,'country':'US'},
        {'PV':6.4,'quartile':75,'country':'US'},
        {'PV':3.2,'quartile':25,'country':'CH'},
        {'PV':4.8,'quartile':50,'country':'CH'},
        {'PV':6.9,'quartile':75,'country':'CH'}]
PV=pd.DataFrame(PV)


df['life_batt']=df.apply(lambda x: get_battery_lifetime(x)[0],axis=1)

# %%
def get_replacements(CAPEX,row,project_life,device_life,fraction,discount_rate):
    
    rep=int(np.ceil(project_life/device_life))-1
    #print('------')
    #print(row.life)
    #print(investment)
    for i in range(rep):
        CAPEX_fut=CAPEX*fraction/(1+discount_rate)**(device_life*(i+1))
        investment=CAPEX+CAPEX_fut
        #print(Batt.Price_battery)
        #print(future_batt)
        if (i==rep-1)&(project_life>device_life*rep):
            investment=investment-((CAPEX_fut*fraction)/(1+discount_rate)**(device_life*(i+1))/device_life*(
                project_life-device_life*(rep+1)))
            #print('####')
            #print(investment)
            #print(rep)
    return investment
def get_replacements_batt(investment,row,Batt,project_life,fraction,discount_rate):
    
    rep=int(np.ceil(project_life/row.life_batt))-1
    #print('------')
    #print(row.life_batt)
    #print(investment)
    for i in range(rep):
        future_batt=Batt.Price_battery*fraction/(1+discount_rate)**(row.life_batt*(i+1))
        investment=investment+future_batt
        #print(Batt.Price_battery)
        #print(future_batt)
        if (i==rep-1)&(project_life>row.life_batt*rep):
            investment=investment-((future_batt*fraction)/(1+discount_rate)**(row.life_batt*(i+1))/row.life_batt*(
                project_life-row.life_batt*(rep+1)))
            #print('####')
            #print(investment)
            #print(rep)
    return investment

# %%
def get_opex(row,project_life,df_prices,discount_rate,EUR_CHF):
    opex_hh=row.Bill # i.e. opex_hp+opex_hh
    opex_pv=96*row.PV_nom
    opex_hp=1.1/100*get_capex_hp(row,20,1,discount_rate,EUR_CHF)# i.e. maintenances costs Fischer
    opex_tank=0
    opex_DHW=0
    opex_batt=0
    opex=opex_pv+opex_batt+opex_tank+opex_DHW+opex_hh
    opex_present_value=np.npv(discount_rate,np.tile(opex,project_life))
    return opex_present_value
def get_opex_no_export(row,project_life,df_prices,discount_rate,EUR_CHF):
    opex_hh=row.Bill+row.E_PV_grid*df_prices.Export_price.mean() # i.e. opex_hp+opex_hh
    opex_pv=96*row.PV_nom
    opex_hp=1.1/100*get_capex_hp(row,20,1,discount_rate,EUR_CHF)# i.e. maintenances costs Fischer
    opex_tank=0
    opex_DHW=0
    opex_batt=0
    opex=opex_pv+opex_batt+opex_tank+opex_DHW+opex_hh
    opex_present_value=np.npv(discount_rate,np.tile(opex,project_life))
    return opex_present_value
def get_capex_hp(row,project_life,fraction,discount_rate,EUR_CHF):
    '''

    '''
    hp_lifetime=20    
    if row.house_type=='SFH15':
        hp_power=4
    elif row.house_type=='SFH45':
        hp_power=6
    else:
        hp_power=16
    cost_hp=1500*hp_power*EUR_CHF #D. Fischer, K.B. Lindberg, H. Madani, C. Wittwer 2016 
    bos_hp=2000*EUR_CHF #D. Fischer, K.B. Lindberg, H. Madani, C. Wittwer 2016 only once
    if project_life/hp_lifetime>1:
        cost_hp=get_replacements(cost_hp,row,project_life,hp_lifetime,fraction,discount_rate)
    return cost_hp

def get_capex_pv(row):
    '''
    '''
    cost_pv=1032*row.PV_nom #PSI
    bos_pv=(240+529+168+190)*row.PV_nom # bos+labour+others+inverter #PSI and Denholm
    return cost_pv+bos_pv
def get_capex_batt(row,project_life,fraction,discount_rate,EUR_CHF):
    
    if row.conf>3:#with battery
        batt=pc.Battery_case(Capacity=row.Capacity,Technology=row.Tech,case=row.cases)
        bos_batt=(2000+(100+(600-190)/1.2)*row.PV_nom)# 
        cost_batt=fraction*(bos_batt+batt.Price_battery*EUR_CHF)#T. Baumann, F. Baumgartner 2017, Denholm
    
        cost_batt=get_replacements_batt(cost_batt,row,batt,
                                       project_life,fraction,discount_rate)
    else:
        cost_batt=0  
        bos_batt=0
    return cost_batt+bos_batt
def get_capex_tank(row,project_life,fraction,discount_rate,EUR_CHF):
    tank_lifetime=20
    if (row.house_type=='SFH100')&((row.conf==2)|(row.conf==3)|(row.conf==6)|(row.conf==7)):
        cost_tank=120*EUR_CHF*(1500*20*0.00116) #i.e. 120 eur/kwh th * 200 liters* 20 delta K * c kWh/(l*K)  #D. Fischer, K.B. Lindberg, H. Madani, C. Wittwer 2016 
        bos_tank=0
        if project_life/tank_lifetime>1:
            cost_tank=get_replacements(cost_tank,row,project_life,tank_lifetime,fraction,discount_rate)
    else:
        cost_tank=0
        bos_tank=0
    return cost_tank+bos_tank
def get_capex_dhw(row,project_life,fraction,discount_rate,EUR_CHF):
    tank_lifetime=20
    
    if ((row.conf==1)|(row.conf==3)|(row.conf==5)|(row.conf==7)):
        cost_DHW=120*EUR_CHF*(200*20*0.00116) #i.e. 120 eur/kwh th * 200 liters* 20 delta K * c kWh/(l*K)  #D. Fischer, K.B. Lindberg, H. Madani, C. Wittwer 2016 
        bos_DHW=0
        if project_life/tank_lifetime>1:
            cost_DHW=get_replacements(cost_DHW,row,project_life,tank_lifetime,fraction,discount_rate)
    else:
        cost_DHW=0
        bos_DHW=0
    return cost_DHW+bos_DHW
def get_numerator(row,project_life,fraction,discount_rate,df_prices,no_export):
    '''
    fraction is for the battery future price (1 is 0 fraction)
    capex includes the pv, HP, battery and DHW tank (and SH tank for SFH100 if needed)
    cost includes replacements and bos
    
    While the literature uses different definitions of bos, here, bos includes all hardware 
    (e.g., inverter), software (e.g., energy management system), and services 
    (e.g., engineering, procurement, and construction) necessary to enable the use of the 
    battery pack for the respective application. 
    bos is considered only once (even with replacement)
    lifespan of hp 20 y
    lifespan of batt variable
    lifespan of tanks 20 y
    lifespan of 
    
    Change rate from EUR to USD 1.1 as of October 2019
    returns 
    capex in present value
    '''
    EUR_CHF=1.1 # 1 Euro = 1.1 CHF
    total_cost_hp=get_capex_hp(row,project_life,fraction,discount_rate,EUR_CHF)
    total_cost_pv=get_capex_pv(row)
    total_cost_batt=get_capex_batt(row,project_life,fraction,discount_rate,EUR_CHF)
    total_cost_tank=get_capex_tank(row,project_life,fraction,discount_rate,EUR_CHF)
    total_cost_dhw=get_capex_dhw(row,project_life,fraction,discount_rate,EUR_CHF)
    capex=total_cost_pv+total_cost_batt+total_cost_hp+total_cost_tank+total_cost_dhw
    if no_export:
        opex=get_opex_no_export(row,project_life,df_prices,discount_rate,EUR_CHF)
    else:
        opex=get_opex(row,project_life,df_prices,discount_rate,EUR_CHF)        
    return capex+opex
def get_lcoes(row,project_life,fraction,discount_rate,df_prices,no_export):
    # working version, not definitive
    num=get_numerator(row,project_life,fraction,discount_rate,df_prices,no_export)
    E_del_pres=np.npv(0.04,np.tile((row.E_hp+row.E_bu+row.E_budhw+row.E_hpdhw+row.E_demand),project_life))
    return num/E_del_pres

# %%
df_prices=pd.read_csv('Input/Prices_2017.csv')

# %%
df_prices.head()
# Out:
#    Unnamed: 0                      index  Price_flat  Price_DT  Export_price  \
# 0           0  2017-01-01 00:00:00+01:00        0.29    0.1646       0.05704
# 1           1  2017-01-01 00:15:00+01:00        0.29    0.1646       0.05704
# 2           2  2017-01-01 00:30:00+01:00        0.29    0.1646       0.05704
# 3           3  2017-01-01 00:45:00+01:00        0.29    0.1646       0.05704
# 4           4  2017-01-01 01:00:00+01:00        0.29    0.1646       0.05194
#
#    Price_flat_mod  Price_DT_mod
# 0          0.1716      0.130034
# 1          0.1716      0.130034
# 2          0.1716      0.130034
# 3          0.1716      0.130034
# 4          0.1716      0.130034

# %%
df['LCOES_exp']=df.apply(lambda x: get_lcoes(x,project_life,fraction,discount_rate,df_prices,False),axis=1)
df['LCOES_noexp']=df.apply(lambda x: get_lcoes(x,project_life,fraction,discount_rate,df_prices,True),axis=1)

# %%
df['CAPEX_PV']=df.apply(lambda x: get_capex_pv(x),axis=1)
df['CAPEX_hp']=df.apply(lambda x: get_capex_hp(x,project_life,fraction,discount_rate,1.1),axis=1)
df['CAPEX_batt']=df.apply(lambda x: get_capex_batt(x,project_life,fraction,discount_rate,1.1),axis=1)
df['CAPEX_tank']=df.apply(lambda x: get_capex_tank(x,project_life,fraction,discount_rate,1.1),axis=1)
df['CAPEX_DHW']=df.apply(lambda x: get_capex_dhw(x,project_life,fraction,discount_rate,1.1),axis=1)

# %%
df.head()
# Out:
#      E_PV_batt       E_PV_bu  E_PV_budhw   E_PV_curt    E_PV_grid     E_PV_hp  \
# 0     0.000000  1.347130e+00    0.000000  407.201892  4191.589898  318.392014
# 1     0.000000  0.000000e+00    5.609831  411.198439  3297.684731  518.154410
# 2     0.000000  8.213075e-01    0.000000  407.201957  3910.627560  617.062475
# 3  1474.265615  2.385262e+00    0.000000  328.867444  3012.606660  205.835722
# 4     0.000000 -1.309508e-13    2.588534  413.656334  3469.832402  227.999014
#
#    E_PV_hpdhw    E_PV_load     E_batt_bu  E_batt_budhw  ...  cycle_to_total  \
# 0    0.000000  1487.614181  0.000000e+00           0.0  ...        0.000000
# 1  705.094334  1468.603198  0.000000e+00           0.0  ...        0.000000
# 2    0.000000  1470.431819  0.000000e+00           0.0  ...        0.000000
# 3    0.000000  1332.895461 -6.954412e-14           0.0  ...        0.449315
# 4  819.726013  1472.665541  0.000000e+00           0.0  ...        0.000000
#
#          Bill  life_batt  LCOES_exp  LCOES_noexp  CAPEX_PV      CAPEX_hp  \
# 0  530.517468         15   0.411715     0.448806   10363.2  10299.507692
# 1  887.925694         15   0.363359     0.382786   10363.2  15449.261538
# 2  751.482802         15   0.401623     0.428912   10363.2  15449.261538
# 3  304.752716         14   0.510233     0.536943   10363.2  10299.507692
# 4  669.114945         15   0.357709     0.382193   10363.2  10299.507692
#
#      CAPEX_batt  CAPEX_tank   CAPEX_DHW
# 0      0.000000         0.0    0.000000
# 1      0.000000         0.0  955.794314
# 2      0.000000         0.0    0.000000
# 3  13179.210259         0.0    0.000000
# 4      0.000000         0.0  955.794314
#
# [5 rows x 101 columns]

# %%
df['CAPEX']=df.iloc[:,-5:].sum(axis=1)

# %%
list_cols=['E_demand','conf','house_type','App_comb','LCOES_exp','LCOES_noexp','CAPEX_PV','CAPEX_hp','CAPEX_batt','CAPEX_tank','CAPEX_DHW','CAPEX']

# %%
df.sort_values(by=['App_comb','conf','house_type']).loc[:,list_cols]
# Out:
#        E_demand  conf house_type  App_comb  LCOES_exp  LCOES_noexp  CAPEX_PV  \
# 8967    1650.60   0.0     SFH100       2.0   0.554449     0.580909   10363.2
# 8973    1637.69   0.0     SFH100       2.0   0.548743     0.573964   10363.2
# 8977    1777.25   0.0     SFH100       2.0   0.546352     0.571664   10363.2
# 8982    3163.31   0.0     SFH100       2.0   0.494693     0.514716   10363.2
# 8986    3591.77   0.0     SFH100       2.0   0.476626     0.494631   10363.2
# 8992    2736.69   0.0     SFH100       2.0   0.511452     0.533458   10363.2
# 8998    1868.79   0.0     SFH100       2.0   0.539556     0.564475   10363.2
# 9003    3560.10   0.0     SFH100       2.0   0.478137     0.496137   10363.2
# 9009    3320.45   0.0     SFH100       2.0   0.485452     0.504632   10363.2
# 9014    1902.00   0.0     SFH100       2.0   0.543070     0.568409   10363.2
# 9019    4140.70   0.0     SFH100       2.0   0.465837     0.482895   10363.2
# 9024    2143.38   0.0     SFH100       2.0   0.530588     0.554006   10363.2
# 9029    2652.94   0.0     SFH100       2.0   0.508866     0.530364   10363.2
# 9034    2903.92   0.0     SFH100       2.0   0.500747     0.521344   10363.2
# 9039    1408.63   0.0     SFH100       2.0   0.562570     0.589825   10363.2
# 9045    1374.11   0.0     SFH100       2.0   0.564002     0.591295   10363.2
# 9048    5335.20   0.0     SFH100       2.0   0.442713     0.458247   10363.2
# 9056    2272.20   0.0     SFH100       2.0   0.522777     0.545019   10363.2
# 9065    1843.83   0.0     SFH100       2.0   0.546141     0.571754   10363.2
# 9070    1722.20   0.0     SFH100       2.0   0.550417     0.576343   10363.2
# 9076    3565.81   0.0     SFH100       2.0   0.483250     0.502713   10363.2
# 9082    2642.10   0.0     SFH100       2.0   0.511484     0.533483   10363.2
# 9085    4493.49   0.0     SFH100       2.0   0.457342     0.473998   10363.2
# 9091    2970.20   0.0     SFH100       2.0   0.495984     0.516054   10363.2
# 9102    2316.88   0.0     SFH100       2.0   0.524144     0.546992   10363.2
# 9106    1684.13   0.0     SFH100       2.0   0.548595     0.574117   10363.2
# 9112    2179.34   0.0     SFH100       2.0   0.528555     0.552179   10363.2
# 9117    1238.27   0.0     SFH100       2.0   0.569067     0.596499   10363.2
# 9122    2010.36   0.0     SFH100       2.0   0.537622     0.562421   10363.2
# 9127    2659.34   0.0     SFH100       2.0   0.512578     0.535090   10363.2
# ...         ...   ...        ...       ...        ...          ...       ...
# 8942    2353.53   7.0      SFH45       3.0   0.545597     0.571116   10363.2
# 8943    5285.80   7.0      SFH45       3.0   0.415115     0.424281   10363.2
# 8944    4032.50   7.0      SFH45       3.0   0.457333     0.471617   10363.2
# 8945    2462.53   7.0      SFH45       3.0   0.534560     0.557767   10363.2
# 8946    5510.67   7.0      SFH45       3.0   0.418666     0.428607   10363.2
# 8947    2530.35   7.0      SFH45       3.0   0.531174     0.553882   10363.2
# 8948    4093.59   7.0      SFH45       3.0   0.449547     0.462893   10363.2
# 8949    1755.19   7.0      SFH45       3.0   0.584050     0.613710   10363.2
# 8950    3579.82   7.0      SFH45       3.0   0.494839     0.511152   10363.2
# 8951    1828.72   7.0      SFH45       3.0   0.588773     0.618167   10363.2
# 8952    3449.71   7.0      SFH45       3.0   0.496784     0.513803   10363.2
# 8953    3864.02   7.0      SFH45       3.0   0.454568     0.469032   10363.2
# 8954    2661.79   7.0      SFH45       3.0   0.520349     0.542630   10363.2
# 8955    3574.39   7.0      SFH45       3.0   0.476460     0.491567   10363.2
# 8956    3047.99   7.0      SFH45       3.0   0.533521     0.552205   10363.2
# 8957    1450.92   7.0      SFH45       3.0   0.610154     0.643310   10363.2
# 8958    2182.69   7.0      SFH45       3.0   0.558592     0.583957   10363.2
# 8959    1162.58   7.0      SFH45       3.0   0.641512     0.677981   10363.2
# 8960    1722.05   7.0      SFH45       3.0   0.582779     0.612729   10363.2
# 8961    1813.10   7.0      SFH45       3.0   0.606130     0.636061   10363.2
# 8963    1655.49   7.0      SFH45       3.0   0.586773     0.616244   10363.2
# 8964    2169.96   7.0      SFH45       3.0   0.553663     0.579027   10363.2
# 26889   4940.12   7.0      SFH45       3.0   0.406497     0.417094   10363.2
# 26890   4056.41   7.0      SFH45       3.0   0.443878     0.457917   10363.2
# 26891   4125.40   7.0      SFH45       3.0   0.441453     0.455957   10363.2
# 26892   1169.95   7.0      SFH45       3.0   0.641795     0.679269   10363.2
# 26898   3608.98   7.0      SFH45       3.0   0.462410     0.478590   10363.2
# 26899   1236.15   7.0      SFH45       3.0   0.638813     0.675909   10363.2
# 26900   3838.06   7.0      SFH45       3.0   0.472729     0.488810   10363.2
# 26903   1460.09   7.0      SFH45       3.0   0.613190     0.646671   10363.2
#
#            CAPEX_hp    CAPEX_batt  CAPEX_tank   CAPEX_DHW         CAPEX
# 8967   41198.030769      0.000000         0.0    0.000000  51561.230769
# 8973   41198.030769      0.000000         0.0    0.000000  51561.230769
# 8977   41198.030769      0.000000         0.0    0.000000  51561.230769
# 8982   41198.030769      0.000000         0.0    0.000000  51561.230769
# 8986   41198.030769      0.000000         0.0    0.000000  51561.230769
# 8992   41198.030769      0.000000         0.0    0.000000  51561.230769
# 8998   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9003   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9009   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9014   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9019   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9024   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9029   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9034   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9039   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9045   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9048   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9056   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9065   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9070   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9076   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9082   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9085   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9091   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9102   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9106   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9112   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9117   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9122   41198.030769      0.000000         0.0    0.000000  51561.230769
# 9127   41198.030769      0.000000         0.0    0.000000  51561.230769
# ...             ...           ...         ...         ...           ...
# 8942   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8943   15449.261538  13179.210259         0.0  955.794314  39947.466112
# 8944   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8945   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8946   15449.261538  13284.869509         0.0  955.794314  40053.125361
# 8947   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8948   15449.261538  13179.210259         0.0  955.794314  39947.466112
# 8949   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8950   15449.261538  13179.210259         0.0  955.794314  39947.466112
# 8951   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8952   15449.261538  13179.210259         0.0  955.794314  39947.466112
# 8953   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8954   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8955   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8956   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8957   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8958   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8959   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8960   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8961   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8963   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 8964   15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26889  15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26890  15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26891  15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26892  15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26898  15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26899  15449.261538  12121.595259         0.0  955.794314  38889.851111
# 26900  15449.261538  13179.210259         0.0  955.794314  39947.466112
# 26903  15449.261538  12121.595259         0.0  955.794314  38889.851111
#
# [26916 rows x 12 columns]

# %%
df[df.house_type=='SFH100'].sort_values(by=['LCOES_exp']).loc[:,list_cols]
# Out:
#        E_demand  conf house_type  App_comb  LCOES_exp  LCOES_noexp  CAPEX_PV  \
# 20918   5441.98   1.0     SFH100       2.0   0.390502     0.398907   10363.2
# 20883   5330.71   1.0     SFH100       2.0   0.394146     0.402844   10363.2
# 21075   5577.43   1.0     SFH100       2.0   0.394448     0.404205   10363.2
# 21452   5285.80   1.0     SFH100       2.0   0.394788     0.403832   10363.2
# 21431   5510.67   1.0     SFH100       2.0   0.395758     0.405962   10363.2
# 21654   5240.76   1.0     SFH100       2.0   0.396532     0.405681   10363.2
# 21353   5176.39   1.0     SFH100       2.0   0.397677     0.407620   10363.2
# 20348   4884.53   1.0     SFH100       2.0   0.397869     0.406358   10363.2
# 21628   4940.12   1.0     SFH100       2.0   0.399917     0.409448   10363.2
# 20206   4897.63   1.0     SFH100       2.0   0.400181     0.409744   10363.2
# 20685   4872.05   1.0     SFH100       2.0   0.400360     0.409973   10363.2
# 20889   4970.68   1.0     SFH100       2.0   0.400460     0.410055   10363.2
# 20587   5057.54   1.0     SFH100       2.0   0.400635     0.410621   10363.2
# 20651   5335.20   1.0     SFH100       2.0   0.401242     0.411851   10363.2
# 21712   4848.98   1.0     SFH100       2.0   0.402008     0.412189   10363.2
# 20604   4858.51   1.0     SFH100       2.0   0.402046     0.411670   10363.2
# 20396   4916.94   1.0     SFH100       2.0   0.402411     0.412117   10363.2
# 20833   4945.81   1.0     SFH100       2.0   0.402455     0.412515   10363.2
# 21356   5154.74   1.0     SFH100       2.0   0.402757     0.413961   10363.2
# 20374   4535.95   1.0     SFH100       2.0   0.403258     0.412619   10363.2
# 21403   4743.23   1.0     SFH100       2.0   0.403583     0.413291   10363.2
# 21200   4938.52   1.0     SFH100       2.0   0.404099     0.414228   10363.2
# 21339   4526.71   1.0     SFH100       2.0   0.404505     0.414275   10363.2
# 21066   4570.51   1.0     SFH100       2.0   0.405733     0.415595   10363.2
# 20382   4996.91   1.0     SFH100       2.0   0.406170     0.416478   10363.2
# 21710   4606.74   1.0     SFH100       2.0   0.406700     0.416645   10363.2
# 20659   4752.62   1.0     SFH100       2.0   0.407152     0.418241   10363.2
# 20586   4249.04   1.0     SFH100       2.0   0.407257     0.417499   10363.2
# 20359   4562.48   1.0     SFH100       2.0   0.407287     0.417425   10363.2
# 20476   4433.86   1.0     SFH100       2.0   0.408276     0.419174   10363.2
# ...         ...   ...        ...       ...        ...          ...       ...
# 15896   1277.71   6.0     SFH100       3.0   0.660446     0.682823   10363.2
# 16340   1216.80   6.0     SFH100       3.0   0.660700     0.682714   10363.2
# 11147   1181.11   6.0     SFH100       2.0   0.661015     0.683275   10363.2
# 16423   1191.59   6.0     SFH100       3.0   0.661045     0.683224   10363.2
# 16452   1265.72   6.0     SFH100       3.0   0.661208     0.683329   10363.2
# 16442   1195.83   6.0     SFH100       3.0   0.661235     0.681926   10363.2
# 15778   1161.09   6.0     SFH100       3.0   0.661483     0.683232   10363.2
# 16240   1276.97   6.0     SFH100       3.0   0.661485     0.683094   10363.2
# 15884   1166.84   6.0     SFH100       3.0   0.662031     0.683909   10363.2
# 12912   1169.95   6.0     SFH100       2.0   0.662045     0.684623   10363.2
# 16298   1172.69   6.0     SFH100       3.0   0.662142     0.684270   10363.2
# 15806   1169.68   6.0     SFH100       3.0   0.662146     0.684077   10363.2
# 12603   1157.20   6.0     SFH100       2.0   0.662199     0.684774   10363.2
# 13144   1152.48   6.0     SFH100       2.0   0.662450     0.684978   10363.2
# 15735   1239.33   6.0     SFH100       3.0   0.662644     0.684722   10363.2
# 15928   1236.15   6.0     SFH100       3.0   0.662940     0.685438   10363.2
# 15720   1282.84   6.0     SFH100       3.0   0.662975     0.684498   10363.2
# 15878   1181.11   6.0     SFH100       3.0   0.663340     0.685557   10363.2
# 12827   1140.39   6.0     SFH100       2.0   0.663630     0.686166   10363.2
# 15845   1191.96   6.0     SFH100       3.0   0.663635     0.685897   10363.2
# 16407   1242.03   6.0     SFH100       3.0   0.664474     0.687016   10363.2
# 15824   1228.38   6.0     SFH100       3.0   0.664624     0.686328   10363.2
# 16306   1169.95   6.0     SFH100       3.0   0.664950     0.687488   10363.2
# 16370   1162.58   6.0     SFH100       3.0   0.665094     0.687062   10363.2
# 15985   1195.62   6.0     SFH100       3.0   0.665253     0.687280   10363.2
# 16275   1157.20   6.0     SFH100       3.0   0.665417     0.687944   10363.2
# 16400   1152.48   6.0     SFH100       3.0   0.665775     0.688257   10363.2
# 16359   1140.39   6.0     SFH100       3.0   0.666190     0.688685   10363.2
# 19518   1344.84   4.0     SFH100       3.0   0.677685     0.701781   10363.2
# 16278   1344.84   6.0     SFH100       3.0   0.678098     0.700524   10363.2
#
#            CAPEX_hp    CAPEX_batt   CAPEX_tank   CAPEX_DHW         CAPEX
# 20918  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20883  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21075  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21452  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21431  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21654  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21353  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20348  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21628  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20206  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20685  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20889  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20587  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20651  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21712  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20604  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20396  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20833  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21356  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20374  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21403  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21200  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21339  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21066  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20382  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 21710  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20659  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20586  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20359  41198.030769      0.000000     0.000000  955.794314  52517.025083
# 20476  41198.030769      0.000000     0.000000  955.794314  52517.025083
# ...             ...           ...          ...         ...           ...
# 15896  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16340  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 11147  41198.030769  13179.210259  7168.457354    0.000000  71908.898382
# 16423  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16452  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16442  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15778  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16240  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15884  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 12912  41198.030769  13179.210259  7168.457354    0.000000  71908.898382
# 16298  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15806  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 12603  41198.030769  13179.210259  7168.457354    0.000000  71908.898382
# 13144  41198.030769  13179.210259  7168.457354    0.000000  71908.898382
# 15735  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15928  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15720  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15878  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 12827  41198.030769  13179.210259  7168.457354    0.000000  71908.898382
# 15845  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16407  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15824  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16306  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16370  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 15985  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16275  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16400  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 16359  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
# 19518  41198.030769  13377.463300     0.000000    0.000000  64938.694070
# 16278  41198.030769  12121.595259  7168.457354    0.000000  70851.283382
#
# [8976 rows x 12 columns]

# %%
#df.to_csv('post_proc_R.csv')

# %%
df.groupby(['house_type','conf','App_comb']).mean().E_hp
# Out:
# house_type  conf  App_comb
# SFH100      0.0   2.0         6788.117306
#                   3.0         6788.143253
#             1.0   2.0         7296.080500
#                   3.0         7300.868982
#             2.0   2.0         7222.092032
#                   3.0         7253.481574
#             3.0   2.0         7219.442328
#                   3.0         7246.765789
#             4.0   2.0         6788.147584
#                   3.0         6788.147662
#             5.0   2.0         7293.637590
#                   3.0         7294.468649
#             6.0   2.0         7212.718257
#                   3.0         7227.366322
#             7.0   2.0         7212.458732
#                   3.0         7226.132049
# SFH15       0.0   2.0          885.720860
#                   3.0          885.720860
#             1.0   2.0          970.483636
#                   3.0          970.818717
#             2.0   2.0          969.050417
#                   3.0          972.663950
#             3.0   2.0          967.066831
#                   3.0          968.744039
#             4.0   2.0          885.720860
#                   3.0          885.720860
#             5.0   2.0          969.220002
#                   3.0          969.593571
#             6.0   2.0          957.747453
#                   3.0          961.359388
#             7.0   2.0          960.302943
#                   3.0          958.798917
# SFH45       0.0   2.0         2261.056744
#                   3.0         2261.061091
#             1.0   2.0         2383.057549
#                   3.0         2383.945671
#             2.0   2.0         2363.569150
#                   3.0         2372.584302
#             3.0   2.0         2361.648774
#                   3.0         2373.431109
#             4.0   2.0         2261.062269
#                   3.0         2261.062282
#             5.0   2.0         2381.739910
#                   3.0         2382.430265
#             6.0   2.0         2354.670132
#                   3.0         2363.821657
#             7.0   2.0         2356.263317
#                   3.0         2360.731759
# Name: E_hp, dtype: float64

# %%
plot_boxplot(df,'LCOES_exp',['house_type','conf','App_comb'])

# %%
plot_boxplot(df,'LCOES_noexp',['house_type','conf','App_comb'])

# %%
plot_boxplot(df,'CAPEX_hp',['house_type','conf'])

# %%
plot_boxplot(df,'CAPEX_batt',['house_type','conf'])

# %%
plot_boxplot(df,'CAPEX_tank',['house_type','conf'])

# %%
plt.plot(df.CAPEX_hp)

# %%
df
# Out:
#          E_PV_batt       E_PV_bu  E_PV_budhw   E_PV_curt    E_PV_grid  \
# 0         0.000000  1.347130e+00    0.000000  407.201892  4191.589898
# 1         0.000000  0.000000e+00    5.609831  411.198439  3297.684731
# 2         0.000000  8.213075e-01    0.000000  407.201957  3910.627560
# 3      1474.265615  2.385262e+00    0.000000  328.867444  3012.606660
# 4         0.000000 -1.309508e-13    2.588534  413.656334  3469.832402
# 5      1397.786376  2.145262e+00    0.000000  328.369595  2807.388405
# 6      1392.034539  0.000000e+00    1.349238  330.376061  2398.846456
# 7         0.000000  1.347130e+00    0.000000  407.201892  4193.399266
# 8         0.000000  8.213075e-01    0.000000  407.201957  3911.312158
# 9      1322.900690  0.000000e+00    0.000000  330.024949  2291.790788
# 10     1386.532890  2.715058e+00    0.000000  328.398861  2807.364283
# 11     1459.941718  2.765058e+00    0.000000  328.756525  3012.578244
# 12        0.000000 -1.309508e-13    4.286007  412.459216  3470.047694
# 13     1317.293889  0.000000e+00    0.180103  329.109912  2292.097692
# 14        0.000000  6.375919e+00    0.000000  407.201957  4412.144975
# 15        0.000000  4.807357e+00    0.000000  407.201915  4945.013763
# 16        0.000000  5.617967e+00    0.000000  407.201892  4013.103008
# 17        0.000000  4.037825e+00    0.000000  407.201892  5096.146328
# 18        0.000000  4.158598e+00    0.000000  407.201910  4626.594781
# 19        0.000000  5.597452e+00    0.000000  407.201957  4475.168060
# 20        0.000000  2.967911e+00    0.000000  407.201892  3719.290051
# 21        0.000000  1.052748e+01    0.000000  407.201910  4753.332186
# 22        0.000000  8.240438e+00    0.000000  407.201957  4359.784412
# 23        0.000000  1.223242e+00    0.000000  407.201957  4777.832230
# 24        0.000000  4.722456e+00    0.000000  407.201957  4390.938948
# 25        0.000000  5.987452e+00    0.000000  407.201957  4466.508121
# 26        0.000000  7.858482e+00    0.000000  407.201957  4483.743444
# 27        0.000000  6.936820e+00    0.000000  407.201957  4344.683631
# 28        0.000000  3.851709e+00    0.000000  407.201905  5152.229135
# 29        0.000000  8.750721e+00    0.000000  407.201892  4901.008400
# ...            ...           ...         ...         ...          ...
# 26886  1298.001166  0.000000e+00    2.449902  329.051377  2295.846581
# 26887  1141.747836  0.000000e+00    0.858756  331.325665  2566.355701
# 26888   775.559214  0.000000e+00    0.524332  330.296834  3530.109125
# 26889  1331.849547  0.000000e+00    0.598734  329.409529  1958.406779
# 26890  1170.146197  0.000000e+00    0.182109  327.623193  2323.670716
# 26891  1244.089959  0.000000e+00    0.712494  330.289035  2422.469198
# 26892   491.110751  0.000000e+00    0.944331  328.937004  3849.582831
# 26893  1361.912479  0.000000e+00    0.652519  329.432091  2497.832182
# 26894   814.974886  0.000000e+00    0.000000  331.279753  3499.788745
# 26895   956.050086  3.924782e-01    0.639912  325.111544  2607.483546
# 26896  1147.203528  0.000000e+00    0.639502  326.731062  2291.725793
# 26897  1015.028477  0.000000e+00    0.544400  327.824092  2444.908457
# 26898  1089.995408  0.000000e+00    0.172109  326.951447  2521.107414
# 26899   548.867411  0.000000e+00    0.920000  327.906236  3863.620773
# 26900  1269.360207  0.000000e+00    0.942177  329.811649  2585.288832
# 26901   788.017182  0.000000e+00    0.251750  330.037214  3632.974198
# 26902  1040.066604  0.000000e+00    1.397308  327.327558  3166.973445
# 26903   554.397916 -4.296520e-10    0.000000  326.064952  3650.254760
# 26904   805.524601  0.000000e+00    0.569912  326.553608  3061.241945
# 26905  1199.661220  0.000000e+00    0.000000  326.802190  2293.550934
# 26906     0.000000  0.000000e+00    9.645974  413.866940  4073.107826
# 26907  1638.941716  9.000000e-01    0.996573  332.861456  2059.478666
# 26908   863.617547  0.000000e+00    1.511322  331.964001  3428.206483
# 26909  1070.569925  1.295885e-01    1.064156  329.205815  2930.209836
# 26910  1056.303965  0.000000e+00    2.079431  328.363113  3168.782195
# 26911  1124.434328  0.000000e+00    1.039265  328.071977  2847.792069
# 26912  1135.485902  0.000000e+00    1.444153  328.560810  2672.599445
# 26913  1058.311849  0.000000e+00    0.953360  330.658779  3035.052916
# 26914  1172.202453  0.000000e+00    1.940708  329.700334  2665.851601
# 26915   945.640349  0.000000e+00    1.213014  330.393497  3213.403764
#
#           E_PV_hp  E_PV_hpdhw    E_PV_load     E_batt_bu  E_batt_budhw  ...  \
# 0      318.392014    0.000000  1487.614181  0.000000e+00      0.000000  ...
# 1      518.154410  705.094334  1468.603198  0.000000e+00      0.000000  ...
# 2      617.062475    0.000000  1470.431819  0.000000e+00      0.000000  ...
# 3      205.835722    0.000000  1332.895461 -6.954412e-14      0.000000  ...
# 4      227.999014  819.726013  1472.665541  0.000000e+00      0.000000  ...
# 5      495.655383    0.000000  1321.653015 -6.954412e-14      0.000000  ...
# 6      167.591616  733.507642  1329.142592  0.000000e+00      1.075000  ...
# 7      318.553273    0.000000  1485.643554  0.000000e+00      0.000000  ...
# 8      626.667562    0.000000  1460.142133  0.000000e+00      0.000000  ...
# 9      439.582824  645.410394  1319.657710  0.000000e+00      1.330000  ...
# 10     512.296330    0.000000  1315.129948 -6.811167e-14      0.000000  ...
# 11     226.763349    0.000000  1325.327463 -6.808478e-14      0.000000  ...
# 12     244.051386  807.382361  1468.181317  0.000000e+00      0.000000  ...
# 13     452.284469  648.936125  1309.122030  0.000000e+00      0.665000  ...
# 14     670.639456    0.000000   909.782811  0.000000e+00      0.000000  ...
# 15     373.346215    0.000000   675.775866  0.000000e+00      0.000000  ...
# 16     322.547904    0.000000  1657.674344  0.000000e+00      0.000000  ...
# 17     388.202569    0.000000   510.556502  0.000000e+00      0.000000  ...
# 18     355.582920    0.000000  1012.606908  0.000000e+00      0.000000  ...
# 19     712.180786    0.000000   805.996863  0.000000e+00      0.000000  ...
# 20     285.741254    0.000000  1990.944008  0.000000e+00      0.000000  ...
# 21     361.958595    0.000000   873.124944  0.000000e+00      0.000000  ...
# 22     658.074477    0.000000   972.843835  0.000000e+00      0.000000  ...
# 23     718.884404    0.000000   501.003285  0.000000e+00      0.000000  ...
# 24     690.161824    0.000000   913.119933  0.000000e+00      0.000000  ...
# 25     687.167793    0.000000   839.279796  0.000000e+00      0.000000  ...
# 26     685.305083    0.000000   822.036152  0.000000e+00      0.000000  ...
# 27     703.634363    0.000000   943.688347  0.000000e+00      0.000000  ...
# 28     384.303948    0.000000   458.558419  0.000000e+00      0.000000  ...
# 29     393.529589    0.000000   695.654514  0.000000e+00      0.000000  ...
# ...           ...         ...          ...           ...           ...  ...
# 26886  725.775303  674.811065  1022.120170  0.000000e+00      0.000000  ...
# 26887  755.352415  700.645777   844.112827  0.000000e+00      0.000000  ...
# 26888  220.610552  800.469490   664.449392  0.000000e+00      1.590000  ...
# 26889  400.881985  598.682540  1729.943450  0.000000e+00      0.817262  ...
# 26890  433.466435  635.662089  1450.814065  0.000000e+00      0.000000  ...
# 26891  456.855752  651.167535  1239.860969  0.000000e+00      0.000000  ...
# 26892  567.852333  720.994589   348.281356  0.000000e+00      2.667838  ...
# 26893  388.230445  661.971522  1111.246020  0.000000e+00      0.322473  ...
# 26894  416.077598  697.498790   564.437407  0.000000e+00      1.185157  ...
# 26895  687.824448  680.566859  1072.618757  1.120000e+00      2.030042  ...
# 26896  702.342115  675.226030  1196.488415  2.795000e+00      0.000000  ...
# 26897  715.203502  680.029241  1150.284536  0.000000e+00      2.357928  ...
# 26898  458.955695  654.858952  1285.470140  0.000000e+00      0.000000  ...
# 26899  553.555425  727.006136   288.644307  4.098248e-01      1.808162  ...
# 26900  464.569595  659.005157  1037.698076  0.000000e+00      0.615000  ...
# 26901  417.970272  700.537382   452.836022  0.000000e+00      1.411438  ...
# 26902  406.193940  688.028814   705.052865  0.000000e+00      2.223652  ...
# 26903  559.400110  713.476860   507.075854  6.150000e-01      1.223735  ...
# 26904  805.939061  718.327243   605.103952  0.000000e+00      2.018166  ...
# 26905  709.356271  678.757616  1134.855981  0.000000e+00      0.000000  ...
# 26906  209.115357  852.666317   848.075953  0.000000e+00      0.000000  ...
# 26907  375.280152  635.859319  1321.046188  0.000000e+00      0.050954  ...
# 26908  410.003094  697.951177   593.282646  0.000000e+00      0.585000  ...
# 26909  399.635394  681.874777   924.005110  0.000000e+00      0.365000  ...
# 26910  406.962741  691.864214   681.567813  0.000000e+00      1.207275  ...
# 26911  393.520521  675.164224   969.287625  0.000000e+00      0.409216  ...
# 26912  380.122290  660.635456  1161.048081  1.773812e+00      1.290000  ...
# 26913  400.123834  677.364826   833.715847  0.000000e+00      1.814622  ...
# 26914  396.399050  672.601119  1103.114901  0.000000e+00      3.095464  ...
# 26915  408.541623  690.375594   740.961789  0.000000e+00      0.635000  ...
#
#               Bill  life_batt  LCOES_exp  LCOES_noexp  CAPEX_PV      CAPEX_hp  \
# 0       530.517468         15   0.411715     0.448806   10363.2  10299.507692
# 1       887.925694         15   0.363359     0.382786   10363.2  15449.261538
# 2       751.482802         15   0.401623     0.428912   10363.2  15449.261538
# 3       304.752716         14   0.510233     0.536943   10363.2  10299.507692
# 4       669.114945         15   0.357709     0.382193   10363.2  10299.507692
# 5       533.170239         14   0.480352     0.499970   10363.2  15449.261538
# 6       456.108095         14   0.437893     0.454836   10363.2  10299.507692
# 7       702.849872         15   0.444334     0.481396   10363.2  10299.507692
# 8       887.532025         15   0.421627     0.448879   10363.2  15449.261538
# 9       680.495631         14   0.431085     0.444601   10363.2  15449.261538
# 10      704.239478         15   0.496903     0.516501   10363.2  15449.261538
# 11      497.640420         15   0.536150     0.562863   10363.2  10299.507692
# 12      821.604902         15   0.380712     0.405171   10363.2  10299.507692
# 13      861.965294         15   0.446675     0.460188   10363.2  15449.261538
# 14      459.651096         15   0.502914     0.546243   10363.2  15449.261538
# 15      108.446056         15   0.667160     0.755485   10363.2  10299.507692
# 16      711.782382         15   0.384815     0.415415   10363.2  10299.507692
# 17      308.012631         15   0.548099     0.615098   10363.2  10299.507692
# 18      345.269885         15   0.506948     0.562135   10363.2  10299.507692
# 19      408.695272         15   0.518155     0.564436   10363.2  15449.261538
# 20      711.270669         15   0.370728     0.398055   10363.2  10299.507692
# 21      357.989756         15   0.524058     0.582291   10363.2  10299.507692
# 22      421.019338         15   0.502861     0.546385   10363.2  15449.261538
# 23      340.178896         15   0.572373     0.628626   10363.2  15449.261538
# 24      607.520735         15   0.472337     0.510444   10363.2  15449.261538
# 25      472.453882         15   0.508176     0.552258   10363.2  15449.261538
# 26      399.365765         15   0.521130     0.567955   10363.2  15449.261538
# 27      582.542893         15   0.472886     0.511016   10363.2  15449.261538
# 28       62.222015         15   0.775936     0.885926   10363.2  10299.507692
# 29      222.545524         15   0.597252     0.670739   10363.2  10299.507692
# ...            ...        ...        ...          ...       ...           ...
# 26886  1915.442063         14   0.521659     0.530230   10363.2  41198.030769
# 26887  1862.750403         14   0.552135     0.562359   10363.2  41198.030769
# 26888   359.160717         15   0.648153     0.687192   10363.2  10299.507692
# 26889   832.439735         15   0.406497     0.417094   10363.2  15449.261538
# 26890   756.291115         15   0.443878     0.457917   10363.2  15449.261538
# 26891   768.251106         15   0.441453     0.455957   10363.2  15449.261538
# 26892   409.533647         15   0.641795     0.679269   10363.2  15449.261538
# 26893   762.427927         14   0.478165     0.494116   10363.2  15449.261538
# 26894   506.353389         15   0.604500     0.635596   10363.2  15449.261538
# 26895  1842.174304         14   0.531150     0.541175   10363.2  41198.030769
# 26896  1904.564563         14   0.517284     0.525782   10363.2  41198.030769
# 26897  1906.789204         14   0.534262     0.543622   10363.2  41198.030769
# 26898   690.956658         15   0.462410     0.478590   10363.2  15449.261538
# 26899   437.327950         15   0.638813     0.675909   10363.2  15449.261538
# 26900   813.934047         14   0.472729     0.488810   10363.2  15449.261538
# 26901   457.511541         15   0.611281     0.644441   10363.2  15449.261538
# 26902   519.214691         15   0.556807     0.582620   10363.2  15449.261538
# 26903   451.956626         15   0.613190     0.646671   10363.2  15449.261538
# 26904  1627.028502         14   0.599999     0.613761   10363.2  41198.030769
# 26905  2316.896097         13   0.532758     0.540981   10363.2  41198.030769
# 26906   491.409986         15   0.499825     0.543296   10363.2  10299.507692
# 26907   767.744522         12   0.430871     0.442666   10363.2  15449.261538
# 26908   479.585629         15   0.581800     0.611369   10363.2  15449.261538
# 26909   570.631198         15   0.528192     0.550483   10363.2  15449.261538
# 26910   611.717717         15   0.561456     0.586755   10363.2  15449.261538
# 26911   763.696438         14   0.540069     0.560601   10363.2  15449.261538
# 26912   738.254371         14   0.491831     0.509509   10363.2  15449.261538
# 26913   610.250066         15   0.527702     0.550486   10363.2  15449.261538
# 26914   643.231666         15   0.495624     0.514231   10363.2  15449.261538
# 26915   784.162689         15   0.595140     0.620958   10363.2  15449.261538
#
#          CAPEX_batt   CAPEX_tank   CAPEX_DHW         CAPEX
# 0          0.000000     0.000000    0.000000  20662.707692
# 1          0.000000     0.000000  955.794314  26768.255852
# 2          0.000000     0.000000    0.000000  25812.461538
# 3      13179.210259     0.000000    0.000000  33841.917952
# 4          0.000000     0.000000  955.794314  21618.502006
# 5      13179.210259     0.000000    0.000000  38991.671798
# 6      13179.210259     0.000000  955.794314  34797.712265
# 7          0.000000     0.000000    0.000000  20662.707692
# 8          0.000000     0.000000    0.000000  25812.461538
# 9      13179.210259     0.000000  955.794314  39947.466112
# 10     12121.595259     0.000000    0.000000  37934.056797
# 11     12121.595259     0.000000    0.000000  32784.302951
# 12         0.000000     0.000000  955.794314  21618.502006
# 13     12121.595259     0.000000  955.794314  38889.851111
# 14         0.000000     0.000000    0.000000  25812.461538
# 15         0.000000     0.000000    0.000000  20662.707692
# 16         0.000000     0.000000    0.000000  20662.707692
# 17         0.000000     0.000000    0.000000  20662.707692
# 18         0.000000     0.000000    0.000000  20662.707692
# 19         0.000000     0.000000    0.000000  25812.461538
# 20         0.000000     0.000000    0.000000  20662.707692
# 21         0.000000     0.000000    0.000000  20662.707692
# 22         0.000000     0.000000    0.000000  25812.461538
# 23         0.000000     0.000000    0.000000  25812.461538
# 24         0.000000     0.000000    0.000000  25812.461538
# 25         0.000000     0.000000    0.000000  25812.461538
# 26         0.000000     0.000000    0.000000  25812.461538
# 27         0.000000     0.000000    0.000000  25812.461538
# 28         0.000000     0.000000    0.000000  20662.707692
# 29         0.000000     0.000000    0.000000  20662.707692
# ...             ...          ...         ...           ...
# 26886  13179.210259  7168.457354  955.794314  72864.692696
# 26887  13179.210259  7168.457354  955.794314  72864.692696
# 26888  12121.595259     0.000000  955.794314  33740.097265
# 26889  12121.595259     0.000000  955.794314  38889.851111
# 26890  12121.595259     0.000000  955.794314  38889.851111
# 26891  12121.595259     0.000000  955.794314  38889.851111
# 26892  12121.595259     0.000000  955.794314  38889.851111
# 26893  13179.210259     0.000000  955.794314  39947.466112
# 26894  12121.595259     0.000000  955.794314  38889.851111
# 26895  13179.210259  7168.457354  955.794314  72864.692696
# 26896  13179.210259  7168.457354  955.794314  72864.692696
# 26897  13179.210259  7168.457354  955.794314  72864.692696
# 26898  12121.595259     0.000000  955.794314  38889.851111
# 26899  12121.595259     0.000000  955.794314  38889.851111
# 26900  13179.210259     0.000000  955.794314  39947.466112
# 26901  12121.595259     0.000000  955.794314  38889.851111
# 26902  12121.595259     0.000000  955.794314  38889.851111
# 26903  12121.595259     0.000000  955.794314  38889.851111
# 26904  13179.210259  7168.457354  955.794314  72864.692696
# 26905  13284.869509  7168.457354  955.794314  72970.351946
# 26906      0.000000     0.000000  955.794314  21618.502006
# 26907  13377.463300     0.000000  955.794314  40145.719153
# 26908  12121.595259     0.000000  955.794314  38889.851111
# 26909  12121.595259     0.000000  955.794314  38889.851111
# 26910  12121.595259     0.000000  955.794314  38889.851111
# 26911  13179.210259     0.000000  955.794314  39947.466112
# 26912  13179.210259     0.000000  955.794314  39947.466112
# 26913  12121.595259     0.000000  955.794314  38889.851111
# 26914  12121.595259     0.000000  955.794314  38889.851111
# 26915  12121.595259     0.000000  955.794314  38889.851111
#
# [26916 rows x 102 columns]

# %%
df[df.conf%2==0].E_budhw.max()
# Out:
# 0.0

# %%
2%2
# Out:
# 0

# %%
df['SS']=(df.E_PV_load+df.E_PV_batt+df.E_PV_bu+df.E_PV_budhw+df.E_PV_hp+df.E_PV_hpdhw)/(df.E_demand+df.E_hp+df.E_hpdhw+df.E_bu+df.E_budhw)*100

# %%
#df.to_csv('post_proc_R.csv')

# %%
#df[~df.hh.isin(list_exclure)].reset_index(drop=True).to_csv('R_plots_wilcox_paired.csv')

# %%
df.keys()
# Out:
# Index(['E_PV_batt', 'E_PV_bu', 'E_PV_budhw', 'E_PV_curt', 'E_PV_grid',
#        'E_PV_hp', 'E_PV_hpdhw', 'E_PV_load', 'E_batt_bu', 'E_batt_budhw',
#        ...
#        'life_batt', 'LCOES_exp', 'LCOES_noexp', 'CAPEX_PV', 'CAPEX_hp',
#        'CAPEX_batt', 'CAPEX_tank', 'CAPEX_DHW', 'CAPEX', 'SS'],
#       dtype='object', length=103)

# %%
df.shape
# Out:
# (26916, 103)

# %%
df.keys()
# Out:
# Index(['E_PV_batt', 'E_PV_bu', 'E_PV_budhw', 'E_PV_curt', 'E_PV_grid',
#        'E_PV_hp', 'E_PV_hpdhw', 'E_PV_load', 'E_batt_bu', 'E_batt_budhw',
#        ...
#        'life_batt', 'LCOES_exp', 'LCOES_noexp', 'CAPEX_PV', 'CAPEX_hp',
#        'CAPEX_batt', 'CAPEX_tank', 'CAPEX_DHW', 'CAPEX', 'SS'],
#       dtype='object', length=103)

# %%
capex_plot=df.groupby([df.App_comb,df.conf,df.house_type]).mean().reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-55-a07d45fa1c69> in <module>
# ----> 1 capex_plot=df.groupby([df.App_comb,df.conf,df.house_type]).mean().reset_index()
#
# ~/.conda/envs/alenv/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4429                 # to ndarray and maybe infer different dtype
#    4430                 level_values = _maybe_casted_values(lev, lab)
# -> 4431                 new_obj.insert(0, name, level_values)
#    4432
#    4433         new_obj.index = new_index
#
# ~/.conda/envs/alenv/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3471         value = self._sanitize_column(column, value, broadcast=False)
#    3472         self._data.insert(loc, column, value,
# -> 3473                           allow_duplicates=allow_duplicates)
#    3474
#    3475     def assign(self, **kwargs):
#
# ~/.conda/envs/alenv/lib/python3.7/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1147         if not allow_duplicates and item in self.items:
#    1148             # Should this be a different kind of error??
# -> 1149             raise ValueError('cannot insert {}, already exists'.format(item))
#    1150
#    1151         if not isinstance(loc, int):
#
# ValueError: cannot insert conf, already exists

# %%
capex_plot.head()

# %%
(df.CAPEX_hp/df.CAPEX).describe()

# %%
(df.CAPEX_PV/df.CAPEX).describe()

# %%
(df.CAPEX_batt/df.CAPEX).describe()

# %%
(df.CAPEX_tank/df.CAPEX).describe()

# %%
(df.CAPEX_DHW/df.CAPEX).describe()

# %%
(df.CAPEX_hp/df.CAPEX)

# %%
capex_plot.keys()

# %%
['conf' in capex_plot.keys()]

# %%
ax = capex_plot.plot(x=capex_plot.conf, y="CAPEX_batt", kind="bar")
capex_plot.plot(x=capex_plot.conf, y="CAPEX_hp", kind="bar", ax=ax, color="C2")
capex_plot.plot(x=capex_plot.conf, y="CAPEX_PV", kind="bar", ax=ax, color="C3")
